# %%
# This is our First STep towards Learning Git and Github
print("Hello, Git and GitHub!")
# This script prints a greeting message to the console.
print("Hello Data Science Enthusiasts! " )
# Out:
# Hello, Git and GitHub!
# Hello Data Science Enthusiasts!

# %%
def factorial(n):
    """Return n! for a non-negative integer n."""
    if not isinstance(n, int):
        raise TypeError("n must be an integer")
    if n < 0:
        raise ValueError("n must be non-negative")
    result = 1
    for i in range(2, n + 1):
        result *= i
    return result

# Examples
print(factorial(0))   # 1
print(factorial(5))   # 120

# Interactive usage
try:
    s = input("Enter a non-negative integer to compute its factorial (or press Enter to skip): ").strip()
    if s:
        num = int(s)
        print(f"{num}! = {factorial(num)}")
except Exception as e:
    print("Error:", e)
# Out:
# 1
# 120
# 5! = 120
